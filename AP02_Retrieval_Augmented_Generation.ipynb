# %% [markdown]
# # Arbeitspaket (AP) 2: Retrieval Augmented Generation (RAG)
#
# **Datenthema:** Jugend, Politik, Umwelt & Partizipation
#
# **Maximale Punktzahl:** 60 Punkte
#
# ---
# ## Hinweise
# - Beantworten Sie alle Aufgaben direkt in diesem Notebook.
# - Ändern Sie Zellen mit dem Hinweis **"Bitte nicht verändern"** nicht.
# - Verwenden Sie, wo möglich, die bereits gegebenen Variablen und Funktionen.
# - Antworten auf Theoriefragen schreiben Sie in Markdown-Zellen.
#
# Die Daten für den RAG-Teil (Texte zu *Jugend, Politik, Umwelt & Partizipation* in deutscher Sprache) müsssen im Ordner `data/` abgelegt werden. Sie benötigen ebenfalls eine `.env`-Datei für die Keys.
#
# ---
# ## Teil A – LLM API-Aufrufe (25 Punkte)

# %% [markdown]
# ### Persönliche Angaben (bitte ergänzen)

# %% [markdown]
# <table>
#   <tr>
#     <td>Vorname:</td>
#     <td>Phil</td>
#   </tr>
#   <tr>
#     <td>Nachname:</td>
#     <td>Frei</td>
#   </tr>
#   <tr>
#     <td>Immatrikulationsnummer:</td>
#     <td>21-548-946</td>
#   </tr>
#   <tr>
#     <td>Modul:</td>
#     <td>Data Science</td>
#   </tr>
#   <tr>
#     <td>Prüfungsdatum / Raum / Zeit:</td>
#     <td>15.12.2025 / Raum: MU O2.001 / 8:00 – 11:45</td>
#   </tr>
#   <tr>
#     <td>Erlaubte Hilfsmittel:</td>
#     <td>w.MA.XX.DS.24HS (Data Science)<br>Open Book, Eigener Computer, Internet-Zugang</td>
#   </tr>
#   <tr>
#   <td>Nicht erlaubt:</td>
#   <td>Nicht erlaubt ist der Einsatz beliebiger Formen von generativer KI (z.B. Copilot, ChatGPT) <br> sowie beliebige Formen von Kommunikation oder Kollaboration mit anderen Menschen.</td>
# </tr>
# </table>

# %% [markdown]
# ## Bewertungskriterien
#
# | **Kategorie**                       | **Beschreibung**                                                                                                                                          | **Punkteverteilung**                |
# |-------------------------------------|------------------------------------------------------------------------------------------------------------------------------------------------------------|-------------------------------------|
# | **Code nicht lauffähig oder Ergebnisse nicht relevant** | Der Code läuft nicht oder erfüllt nicht die Anforderungen des Aspekts (z. B. Bilder werden nicht geladen, die Textausgabe der Extraktion fehlt, Bounding Boxes werden nicht angezeigt). | **0 Punkte**                       |
# | **Code lauffähig, aber mit gravierenden Mängeln**       | Der Code läuft, jedoch fehlen zentrale Teile der Funktionalität eines Aspekts (z. B. unvollständige Extraktion von Bildinformationen oder Fehler bei der Definition eines Schemas). | **25% der max. erreichbaren Punkte** |
# | **Code lauffähig, aber mit mittleren Mängeln**          | Der Code läuft und liefert teilweise korrekte Ergebnisse für einen Aspekt, aber wichtige Details fehlen (z. B. ungenaue Bounding Boxes, unvollständige Integration der extrahierten Daten). | **50% der max. erreichbaren Punkte** |
# | **Code lauffähig, aber mit minimalen Mängeln**          | Der Code erfüllt die Anforderungen eines Aspekts weitgehend, aber kleinere Fehler oder Abweichungen (z. B. nicht robust Extraktionsdaten, kleinere Schemaabweichungen, Prompt zu wenig stringent formuliert -> teilweise unstabile Output)sind vorhanden. | **75% der max. erreichbaren Punkte** |
# | **Code lauffähig und korrekt**                         | Der Code erfüllt die Anforderungen des Aspekts vollständig und liefert die erwarteten Ergebnisse ohne Fehler (z. B. korrekte Extraktion, vollständige Bounding Boxes, saubere Integration). | **100% der max. erreichbaren Punkte** |
#
# ---

# %% [markdown]
# ### A0. Setup (0 Punkte)
#
# Führen Sie diese Zellen aus, nachdem Sie die `.env` Datei mit Ihren API-Keys in den Codespace gezogen haben.

# %%
#!pip install openai dotenv

# %%
import os
import random
from openai import OpenAI
from dotenv import load_dotenv

# %%
# === A0. Setup (Bitte Schlüssel nur lokal eintragen, nicht ins Versionskontrollsystem hochladen) ===
load_dotenv()
openai_api_key = os.getenv("OPENAI_API_KEY")
deepinfra_api_key = os.getenv("DEEPINFRA_API_KEY")


# OpenAI-Client
openai_client = OpenAI(api_key=openai_api_key)

# Deepinfra-Client (OpenAI-kompatible API)
deepinfra_client = OpenAI(
    api_key=deepinfra_api_key,
    base_url="https://api.deepinfra.com/v1/openai",
)

print("Setup abgeschlossen.")
# Out:
# Setup abgeschlossen.

# %% [markdown]
# ### A1. Funktion `ask_openai` (10 Punkte)
#
# Implementieren Sie eine Funktion `ask_openai`, die eine Anfrage mit Kontext an das OpenAI-Chat-API schickt und die Antwort als String zurückgibt.
#
# **Anforderungen:**
# 1. Signatur:
#    ```python
#    def ask_openai(user_input: str, context: str) -> str:
#        ...
#    ```
# 2. Verwenden Sie den bereits definierten `openai_client` aus A0.
# 3. Nutzen Sie das Modell `"gpt5-mini"`.
# 4. Die Funktion soll **nur den Textinhalt** der Antwort zurückgeben (ohne zusätzliche Prints).
# 5. Der Kontext soll in den Systemprompt (injected) werden.
#
# Testen Sie Ihre Funktion danach mit **zwei Aufrufen**:
# - einmal mit dem Prompt: *"Schreibe ein Haiku über Rekursion in der Programmierung."*
# - einmal mit dem Prompt: *"Erkläre in einfachen Worten, was der Parameter `temperature` bei LLMs macht."*
#
# Drucken Sie beide Antworten aus.

# %%
user_input1 = "Schreibe ein Haiku über Rekursion in der Programmierung."

context1 = """
Rekursion ist eine Technik in der Programmierung, bei der eine Funktion sich selbst aufruft, um ein Problem in kleinere Teilprobleme zu zerlegen. 
Typischerweise gibt es dabei eine sogenannte Basisbedingung, bei der die Funktion ohne weiteren Selbstaufruf endet. 
Dadurch lassen sich komplexe Strukturen wie Bäume oder verschachtelte Listen oft sehr elegant bearbeiten. 
Allerdings kann Rekursion auch zu Fehlern führen, wenn die Basisbedingung fehlt oder nie erreicht wird. 
In vielen Fällen gibt es sowohl eine rekursive als auch eine iterative Lösung, die sich in Verständlichkeit und Effizienz unterscheiden können.
"""

user_input2 = "Erkläre in einfachen Worten, was der Parameter `temperature` bei LLMs macht."
context2 = """
Der Parameter 'temperature' steuert bei vielen Sprachmodellen, wie kreativ oder deterministisch die Antworten sind. 
Bei einer niedrigen Temperatur (z.B. 0.1) wählt das Modell eher die wahrscheinlichsten Worte und verhält sich dadurch konservativ und vorhersehbar. 
Bei einer höheren Temperatur (z.B. 0.8 oder 1.0) werden auch unwahrscheinlichere Worte stärker berücksichtigt, was zu vielfältigeren und kreativeren Antworten führt. 
Zu hohe Werte können allerdings dazu führen, dass die Ausgabe unzusammenhängend oder unsinnig wird. 
Die Wahl einer passenden Temperatur hängt daher vom Anwendungsfall ab, etwa ob man eher präzise Fakten oder kreative Ideen haben möchte.
"""

# %%
# def ask_openai(user_input: str, context: str) -> str:

#     """
#     TODO (A1): Implementieren Sie diese Funktion.
#     Anforderungen siehe Aufgabenstellung oben.
#     """
#     system_prompt = ""
    
#     return

# %%
MODEL = "gpt-5-mini"
TEMPERATURE = 0.7
MAX_TOKENS = 100

def ask_openai(user_input: str, context: str) -> str:
    response = openai_client.chat.completions.create(
        model = MODEL,
        messages=[
            {"role": "system", "content": context},
            {"role": "user", "content": user_input}
        ]
    )
    reply = response.choices[0].message.content
    return reply

# %%
# the two executions
print(ask_openai(user_input1, context1))

print(ask_openai(user_input2, context2))
# Out:
# Funktion ruft sich
# kleine Probleme zerlegt
# Basis schafft Ruhe
# Kurz und einfach:
#
# - Temperature ist ein Regler für die Zufälligkeit bei der Texterzeugung.
# - Niedrige Werte (z. B. 0–0.2): das Modell wählt die wahrscheinlichsten Wörter. Antworten sind sehr vorhersehbar und sachlich.
# - Mittlere Werte (z. B. 0.5–0.8): mehr Vielfalt und etwas Kreativität, aber meist noch sinnvoll.
# - Hohe Werte (z. 1.0 und höher): das Modell probiert ungewöhnlichere Wörter – die Ausgabe kann kreativer, aber auch inkohärenter oder fehleranfälliger werden.
# - Praktischer Tipp: Verwende niedrige Temperatur für Fakten/Aufgaben, bei denen Genauigkeit wichtig ist, und höhere Temperatur für kreative Texte oder Ideenfindung.
#
# Eine einfache Analogie: Temperature ist wie ein Knopf, der von „sicher und vorhersehbar“ zu „verspielt und überraschend“ dreht.

# %% [markdown]
# ### A2. Deepinfra-Aufruf korrigieren und erweitern (10 Punkte)
#
# Unten finden Sie einen (bewusst) fehlerhaften Beispielaufruf an ein Modell über die Deepinfra-API.
# **Ihre Aufgaben:**
#
# 1. **Korrigieren** Sie den Aufruf so, dass er syntaktisch korrekt ist und mit dem `deepinfra_client` funktioniert.
#    - Achten Sie insbesondere auf Parameter-Namen und den Zugriff auf das Antwortobjekt.
# 2. Erweitern Sie den Code so, dass **zwei Gesprächsrunden** mit dem Modell stattfinden:
#    - Erste User-Frage: *"Nenne zwei unterschiedliche Möglichkeiten, wie Jugendliche sich für den Umweltschutz politisch engagieren können."*
#    - Zweite User-Frage: *"Erläutere die zweite Möglichkeit etwas genauer."*
#    Verwenden Sie dafür die gleiche `messages`-Liste und fügen Sie nur die neue Nutzer-Nachricht und die Assistenten-Antwort hinzu.
# 3. Implementieren Sie eine einfache **Längenbegrenzung**:
#    Wenn die endgültige Antwort-Variable mehr als **400 Zeichen** enthält, kürzen Sie sie auf 400 Zeichen und hängen Sie `"..."` an.
#
# Verwenden Sie ein geeignetes deutschsprachiges oder multilinguales Modell aus Deepinfra (z.B. ein Llama- oder Mixtral-Chatmodell).

# %%
# A2. Deepinfra-Aufruf – fehlerhafte Ausgangsversion
# TODO (A2): Korrigieren und erweitern Sie diesen Code.
openai_client2 = OpenAI(
    api_key=deepinfra_api_key,
    base_url="https://api.deepinfra.com/v1/openai",
)



chat_completion = openai_client2.chat.completions.create(
    model="meta-llama/Llama-4-Maverick-17B-128E-Instruct-FP8",
    messages=[
    {"role": "system", "content": "Du bist eine sachliche, gut informierte Assistenz."},
    {"role": "user", "content": "Nenne zwei unterschiedliche Möglichkeiten, wie Jugendliche sich für den Umweltschutz politisch engagieren können."},
    {"role": "assistant", "content": "Erläutere die zweite Möglichkeit etwas genauer."}

    ],
    temperature=0.8
)

# TODO (A2):
# 1. Fehler korrigieren
# 2. Zweite Gesprächsrunde hinzufügen (weitere user-Nachricht + neue completion)
# 3. Antwort ggf. auf 400 Zeichen kürzen und ausgeben
print

print(chat_completion.choices[0].message.content)
# Out:
# Jugendliche können sich politisch für den Umweltschutz engagieren, indem sie an Demonstrationen und Klimastreiks teilnehmen, um auf die Dringlichkeit des Klimaschutzes aufmerksam zu machen und politische Entscheidungsträger unter Druck zu setzen. Sie können auch in Umweltorganisationen oder -initiativen mitarbeiten, um konkrete Projekte und Kampagnen zu unterstützen, die sich für den Schutz der Umwelt einsetzen.

# %%
# MODEL = "meta-llama/Llama-4-Maverick-17B-128E-Instruct-FP8"
# TEMPERATURE = 0.8
# MAX_TOKENS = 100

# user_input3 = "Nenne zwei unterschiedliche Möglichkeiten, wie Jugendliche sich für den Umweltschutz politisch engagieren können."

# context3 = "Du bist eine sachliche, gut informierte Assistenz."

# def ask_llama(user_input: str, context: str) -> str:
#     response = openai_client.chat.completions.create(
#         model=MODEL,
#         messages=[
#             {"role": "system", "content": context},
#             {"role": "user", "content": user_input}
#         ],
#         temperature=TEMPERATURE,
#         max_tokens=MAX_TOKENS
#     )
#     reply = response.choices[0].message.content
#     return reply

# # Execute the function and print the result
# result = ask_llama(user_input3, context3)
# print(result)

# %%
# MODEL = "gpt-5-mini"
# TEMPERATURE = 0.7
# MAX_TOKENS = 100

# def ask_openai(user_input: str, context: str) -> str:
#     response = openai_client.chat.completions.create(
#         model = MODEL,
#         messages=[
#             {"role": "system", "content": context},
#             {"role": "user", "content": user_input}
#         ]
#     )
#     reply = response.choices[0].message.content
#     return reply

# %% [markdown]
# ### A3. Kurzfrage: Unterschiedliche Provider (5 Punkte)
#
# Beantworten Sie die folgende Frage in **3–4 Sätzen** in der Markdown-Zelle darunter:
#
# > Nennen Sie **einen Vorteil** der Nutzung eines gehosteten Dienstes wie OpenAI im Vergleich zu einem selbst gehosteten Modell,
# > und nennen Sie **mindestens einen Nachteil bzw. ein Risiko**.
#
# Gehen Sie dabei kurz auf Aspekte wie zum Beispiel Leistung, Kosten, Flexibilität oder Datenschutz ein.

# %% [markdown]
# **Antwort A3:**
#
# Vorteil eines gehosteten Diesnstes wie OpenAI:
# Grösse & Erfahrung von OpenAI: OpenAI verfügt über grosse Rechenzentren, Ressourcen und Personal, um ihre KI-Systeme unterhalten zu können. Dies könnte bei einem KMU oder einem anderen Unternehmen nicht der Fall sein, und es würde zu viel Geld in Anspruch nehmen, dies selbst zu erarbeiten. Desshalb könnte man dies als möglichen Vorteil von OpenAI i.Vgl. zu einer selbst-gehosteten Lösung werten.
# Nachteil eines gehosteten Dienstes wie OpenAI:
# Datenschutz: OpenaAI ist in den Vereinigten Staaten ansässig und unterliegt somit US-Rechtssprechung wie etwa der Cloud Act. Dieses Gesetz etwa verlangt, dass US-Unternehmen aus Anfrage der US-Behörden die Inhalte Ihrer Kunden zur Verfügung stellen müssen (grob). Dies ist ein Nachteil

# %% [markdown]
# ---
# ## Teil B – Retrieval-Augmented Generation (RAG) (35 Punkte)
#
# In diesem Teil arbeiten Sie mit einer kleinen RAG-Pipeline.
# Die zugrundeliegenden Texte behandeln das Thema **"Jugend, Politik, Umwelt & Partizipation"** in deutscher Sprache.
#
# Die folgenden Objekte werden in vorbereiteten Zellen erstellt:
# - `documents`: Liste von Rohtexten (z.B. aus PDF- oder Textdateien)
# - `chunks`: Liste von Textchunks
# - `embedder`: Objekt mit einer Methode `.encode(texts, convert_to_numpy=True)`
# - `index`: ein FAISS-Index, der Embeddings von `chunks` enthält
#
# Sie sollen nun die fehlenden Teile der Pipeline implementieren bzw. anpassen.

# %% [markdown]
# ### B0. RAG-Setup (0 Punkte – bitte nicht verändern)
#
# Diese Zelle lädt die Dokumente, erzeugt Chunks, berechnet Embeddings und baut den FAISS-Index auf.
# **Verändern Sie diese Zelle nicht.**

# %%
# === B0. RAG-Setup (Bitte nicht verändern) ===
import os
from typing import List
import glob
from PyPDF2 import PdfReader
import numpy as np
from langchain_text_splitters import RecursiveCharacterTextSplitter
import pickle
from sentence_transformers import SentenceTransformer
import faiss

# Dokumente Laden

DATA_DIR = "data/*.pdf"  # Ordner mit Texten zu "Jugend, Politik, Umwelt & Partizipation"

text = ""

for pdf_path in glob.glob(DATA_DIR):
    with open(pdf_path, "rb") as f:
        reader = PdfReader(f)
        for page in reader.pages:
            page_text = page.extract_text()
            if page_text:
                text += " " + page_text

# Split into chunks

splitter_a = RecursiveCharacterTextSplitter(
    chunk_size=2500,
    chunk_overlap=250
)

chunks = splitter_a.split_text(text)

print(f"Anzahl Chunks: {len(chunks)}")

# 3. Embedder und Embeddings
embedder = SentenceTransformer("sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2")
embeddings = embedder.encode(chunks, convert_to_numpy=True)

# 4. FAISS-Index erstellen
dim = embeddings.shape[1]
index = faiss.IndexFlatL2(dim)
index.add(embeddings)

print("RAG-Setup abgeschlossen.")


os.makedirs("faiss", exist_ok=True)
faiss.write_index(index, "faiss/faiss_exam.index")
with open("faiss/chunks_exam.pkl", "wb") as f:
    pickle.dump(chunks, f)
# Out:
# Anzahl Chunks: 92
# RAG-Setup abgeschlossen.

# %% [markdown]
# ### Run in case of crash later on

# %%
# index = faiss.read_index("faiss/faiss_exam.index")

# with open("faiss/chunks_exam.pkl", "rb") as f:
#    chunks = pickle.load(f)

# %% [markdown]
# ### B1. Funktion `retrieve_texts` korrigieren (10 Punkte)
#
# Die folgende Funktion soll zu einer Anfrage (`query`) die **Top-`k` ähnlichsten Chunks** zurückgeben.
# Die Implementierung ist fehlerhaft.
#
# **Ihre Aufgaben:**
# 1. Korrigieren Sie die Funktion so, dass sie:
#    - die Query korrekt mit dem `embedder` embedden kann,
#    - den FAISS-Index `index` korrekt abfragt und
#    - eine **Liste von Strings** mit den gefundenen Chunks zurückgibt.
# 2. Achten Sie insbesondere auf die richtige Form der Embedding-Arrays und den Umgang mit den Indizes.
#
# Verwenden Sie die bereits existierenden Objekte `index`, `chunks` und `embedder`.

# %%
# from typing import List

# def retrieve_texts(query: str, k: int, index, chunks: List[str], embedder) -> List[str]:
#     """Gibt die Top-k ähnlichsten Chunks für eine Query zurück.

#     TODO (B1): Funktion korrigieren.
#     """
#     # FEHLERHAFTE BEISPIELIMPLEMENTIERUNG:
#     query_emb = embedder.encode(query, convert_to_numpy=True)  # Form kann problematisch sein
#     distances, indices = index.search(query_emb, k)  # hier kann ein Fehler auftreten
#     return [chunks[indices]]  # ebenfalls fehlerhaft

# # Sie können die Funktion z.B. mit einer Test-Query ausprobieren:
# test_query = "Wie können Jugendliche sich politisch für den Klimaschutz engagieren?"
# try:
#     test_results = retrieve_texts(test_query, k=3, index=index, chunks=chunks, embedder=embedder)
#     for i, r in enumerate(test_results, start=1):
#         print(f"Chunk {i} (Ausschnitt):", r[:200], "\n---\n")
# except Exception as e:
#     print("Fehler bei Testabfrage (erwartet, solange die Funktion noch nicht korrigiert ist):", e)

# %%
from typing import List

def retrieve_texts(query: str, k: int, index, chunks: List[str], embedder) -> List[str]:
    """Gibt die Top-k ähnlichsten Chunks für eine Query zurück.

    TODO (B1): Funktion korrigieren.
    """
    # FEHLERHAFTE BEISPIELIMPLEMENTIERUNG:
    query_emb = embedder.encode([query], convert_to_numpy=True)  # Form kann problematisch sein
    distances, indices = index.search(query_emb, k)  # hier kann ein Fehler auftreten
    retrieved = [chunks[i] for i in indices[0]]
    return retrieved  # ebenfalls fehlerhaft

# Sie können die Funktion z.B. mit einer Test-Query ausprobieren:
test_query = "Wie können Jugendliche sich politisch für den Klimaschutz engagieren?"
try:
    test_results = retrieve_texts(test_query, k=3, index=index, chunks=chunks, embedder=embedder)
    for i, r in enumerate(test_results, start=1):
        print(f"Chunk {i} (Ausschnitt):", r[:200], "\n---\n")
except Exception as e:
    print("Fehler bei Testabfrage (erwartet, solange die Funktion noch nicht korrigiert ist):", e)
# Out:
# Chunk 1 (Ausschnitt): Gerechtigkeit und dem Zustand des Bildungswesens derzeit zu den
# wichtigsten Problemen. Die Demokratie hat einen hohen Stellenwert für
# sie. Daraus ergibt sich auch eine hohe Erwartung junger Menschen
# ---
#
# Chunk 2 (Ausschnitt): der Befragten hat schon einmal an einem Freitag fürs Klima gestreikt.
# • Mehr als die Hälfte hat schon einmal Aktionen oder Petitionen für die Umwelt
# im Internet unterstützt.
# Für Umwelt- und Klimas
# ---
#
# Chunk 3 (Ausschnitt): Onlinepetitionen unterstützt
# an Demonstrationen
# teilgenommen
# in einer Natur- oder Umwelt-
# schutzgruppe mitgearbeitet
# Aktionstage organisiert
# in einer Partei aktiv gewesen 57
# 33
# 22
# 15
# 1238
# 65
# 7
# ---

# %% [markdown]
# ### B2. RAG-Antwortfunktion `answer_query` anpassen (10 Punkte)
#
# Unten sehen Sie eine Funktion `answer_query`, die eine Nutzerfrage beantwortet, indem sie:
# 1. mit `retrieve_texts` passende Chunks zum Thema findet,
# 2. diese als Kontext an das LLM schickt und
# 3. eine Antwort generiert.
#
# Die Funktion ist noch nicht korrekt auf das Thema **"Jugend, Politik, Umwelt & Partizipation"** und auf RAG zugeschnitten.
#
# **Ihre Aufgaben:**
# 1. Passen Sie den `system_prompt` an die neue Domäne an und geben sie klare Anweisungen wie mit dem Kontext umzugehen ist.
# 3. Verwenden Sie das Modell `"gpt-5-mini"` über den `openai_client` aus Teil A.
# 4. Wählen Sie einen sinnvollen Standardwert für `k`und kommentieren Sie in **einem kurzen Kommentar im Code**, warum diese Wahl für diesen Anwendungsfall plausibel ist.

# %%
# def answer_query(query: str, k: int, index, chunks: List[str], embedder, client: OpenAI) -> str:
#     """Beantwortet eine Nutzerfrage mittels RAG.

#     TODO (B2):
#     - Prompt anpassen
#     - Sicherstellen, dass nur Kontext verwendet wird
#     - openai_client und gpt-5-mini nutzen
#     """
#     retrieved_chunks = retrieve_texts(query, k, index, chunks, embedder)
#     context = "\n\n---\n\n".join(retrieved_chunks)

#     system_prompt = (
#         "Du bist eine hilfreiche Assistenz, die Fragen zu MEDIZINISCHEN LEITLINIEN beantwortet. "
#         "(TODO: Dies ist noch nicht an die neue Domäne angepasst.)"
#     )

#     messages = [
#         {"role": "system", "content": system_prompt},
#         {"role": "user", "content": f"Kontext:\n{context}\n\nFrage: {query}"},
#     ]

#     completion = client.chat.completions.create(
#         model="gpt-5-mini",
#         messages=messages,
#     )

#     return completion.choices[0].message.content.strip()

# # Beispielaufruf (wenn B1 und B2 korrekt implementiert sind):
# example_query = "Welche Formen politischer Beteiligung von Jugendlichen im Umweltschutz werden im Text genannt?"
# try:
#     answer = answer_query(example_query, k=, index=index, chunks=chunks, embedder=embedder, client=openai_client)
#     print(answer)
# except Exception as e:
#     print("Fehler bei Beispielaufruf (erwartet, solange B1/B2 noch nicht fertig sind):", e)

# %%
def answer_query(query: str, k: int, index, chunks: List[str], embedder, client: OpenAI) -> str:
    """Beantwortet eine Nutzerfrage mittels RAG.

    TODO (B2):
    - Prompt anpassen
    - Sicherstellen, dass nur Kontext verwendet wird
    - openai_client und gpt-5-mini nutzen
    """
    retrieved_chunks = retrieve_texts(query, k, index, chunks, embedder)
    context = "\n\n---\n\n".join(retrieved_chunks)

    system_prompt = (
        "Du bist eine hilfreiche Assistenz, die Fragen zu Politik, Umwelt und Literatur versucht zu beantworten. "
        "Bitte beantworte nur Fragen mit dem dir zur Verfügung stehenden wissen. Wenn du aus deinen Aufzeichnungen nicht in den Kontext passt, so sage, dass du es nicht weisst."
    )

    messages = [
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": f"Kontext:\n{context}\n\nFrage: {query}"},
    ]

    completion = client.chat.completions.create(
        model="gpt-5-mini",
        messages=messages,
    )

    return completion.choices[0].message.content.strip()

# Beispielaufruf (wenn B1 und B2 korrekt implementiert sind):
example_query = "Welche Formen politischer Beteiligung von Jugendlichen im Umweltschutz werden im Text genannt?"
try:
    answer = answer_query(example_query, k=1, index=index, chunks=chunks, embedder=embedder, client=openai_client)
    print("Top1 Chunk:" , chunks[:200], "...")
    print(answer)
    
except Exception as e:
    print("Fehler bei Beispielaufruf (erwartet, solange B1/B2 noch nicht fertig sind):", e)
# Out:
# Top1 Chunk: ['Politische  \nBildung  \nIntersektional \nFachbereich politische Bildung und plurale  \nDemokratie der Bundeszentrale für politische  \nBildung 2 3Inhaltsverzeichnis\nVorwort  \nPeggy Piesche – Fachbereichsleitung \n„Politische Bildung und plurale  \nDemokratie“\nEinleitung  \nTeam – Fachbereich  \n„Politische Bildung und plurale  \nDemokratie“\n1. Rassismuskritische intersektionale \npolitische Bildungsarbeit für mich als \nSchwarze Queer-Feministin  \nKatja Kinder\n2. Romnja* und Sintize* im Kontext \nemanzipatorischer feministischer  \nNetzwerke und Geschichte(n) \nRomaniPhen e. V.\n3. Ein Prozess des Verlernens,  \nNeulernens und Wiedererlernens \nJosephine Akinyosoye und  \nJuliana Kolberg\n4. Intersektionale Bildungsarbeit \nerkennt die Expertisen von vulnerabili-\nsierten Communities explizit an! \nMaisha M. Auma\n5. Intersektionale politische  \nBildung – empowernd, solidarisch, \nverantwortungsvoll \nTuĝba Tanyılmaz, Ed Grewe,  \nBetül Torlak\n6. Solidarische, kollektive und interge-\nnerationelle Räume in der politischen \nBildung – ein intersektionaler Ansatz \nOlenka Bordo Benavides \n \n \n4\n \n \n \n6\n \n \n \n10\n \n \n \n12\n \n \n \n14\n \n \n \n16\n \n \n \n \n18\n \n \n \n207. Wir machen nicht die gleichen  \nRassismuserfahrungen \nLaura Schrader\n8. Die Dominanzgesellschaft(en)  \nherausfordern, statt  \nSchaufensterpolitik zu betreiben \nGLADT e. V.\n9. Resistance and Civic Education \nthrough Multilingual  \nDocumentation \nA conversation between Jennifer \nKamau and Denise Garcia Bergt\n10. Was es konkret braucht.  \nEine Vision für die allernächste  \nZukunft \nProjektteam „MEGA – Media and  \nEmpowerment for German Asians“  \nvon korientation\n11. Between Practicing Justice and \nWishful Thinking \nMay Zeidani Yufanyi\n12. if not us, then who?  \n(Illustration) \nEstera Iordan\nBeitragende Organisationen  \nund Personen\nImpressum \n \n22\n \n \n \n25\n \n \n \n \n28\n \n \n \n \n \n32\n \n \n34\n \n \n36\n \n38\n43 4Diese Broschüre ist eine Einladung, eine Einladung zur Reflexion. Denn in den fol-\ngenden Texten beantworten erfahrene Bildungsarbeitende nicht nur die Frage, was \neine intersektionale politische Bildung auszeichnet. Sie nehmen uns vielmehr mit \nin ihre ganz persönlichen Erfahrungen und Perspektiven, die ihre praktische Arbeit \nprägen. Dabei geht es um Fragen, wie und mit welcher Haltung politische Bildung \nkonzipiert und durchgeführt wird, worauf und auf wen das intersektional in der \npolitischen Bildung zielt und vor allem, was das mit uns selbst zu tun hat. Die Texte', 'prägen. Dabei geht es um Fragen, wie und mit welcher Haltung politische Bildung \nkonzipiert und durchgeführt wird, worauf und auf wen das intersektional in der \npolitischen Bildung zielt und vor allem, was das mit uns selbst zu tun hat. Die Texte \nladen ein, das eigene Handeln in der politischen Bildungsarbeit zu reflektieren und \nmachen erfahrbar, wie die großen Ziele einer breiten und einschließenden Teilhabe-\nmöglichkeit in gesellschaftspolitischen Bildungsprozessen erreicht werden können. \nOft sprechen wir über die Bedarfe und Teilhabebedingungen von marginalisierten \nGruppen, wollen politische Bildung so gestalten, dass Barrieren von Be/Hinderung \nabgebaut oder zumindest heruntergefahren werden. Wir machen uns Gedanken \ndarüber, wie viel ‚diversity‘ in den Formaten der politischen Bildung erreicht werden \nkann und ob wir als Träger, Institutionen oder Akteur*innen der politischen Bildung \nnoch mehr (oder weniger) in dieser Hinsicht handeln müssen. Diese Handlungen \nund Überlegungen bewegen sich oft auf der Metaebene, gehen davon aus, dass \ndem Feld der politischen Bildung lediglich verschiedene Inhalte, Menschen oder \nGruppen hinzuzufügen sind. Damit stößt politische Bildungsarbeit aber immer \nwieder an Grenzen, die aufzeigen, dass die Diversität unserer pluralen Gesellschaft \nnicht in ihrer Gänze abgebildet wird. Das ist frustrierend und gibt oft Anlass zu \nKonflikten bei Frag ...
# Aus dem Text werden folgende Beteiligungsformen genannt:
#
# - Mitarbeit in Jugendverbänden und allgemeines ehrenamtliches Engagement für Umwelt/Klima
# - Mitgliedschaft und aktive Mitwirkung im Jugendprojektbeirat (Diskussionen, Feedback, Impulse)
# - Mitwirkung an Untersuchungen (Kommentieren von Moderationsleitfäden und Fragebögen, Reflexion und Diskussion der Ergebnisse)
# - Moderation und Betreuung einer Online-Community
# - Teilnahme an der Beteiligungswerkstatt „Youth Lab“ (Formulieren von Forderungen an die Umweltpolitik)
# - Teilnahme an Fridays-for-Future-Protesten (Klimastreiks)
# - Unterstützung von Aktionen oder Petitionen für die Umwelt im Internet (Online-Aktionen)

# %% [markdown]
# ### B3. Einfache Retrieval-Sanity-Checks (5 Punkte)
#
# Erweitern Sie die Funktion `answer_query` aus B2 wie folgt:
#
# 1. **Vor dem LLM-Aufruf** soll ein kurzer Ausschnitt (ca. die ersten 200 Zeichen) des **besten (Top-1) Chunks** ausgegeben werden, z.B. mit `print("Top-1 Chunk:", ...)`.
# 2. Falls aus irgendeinem Grund **keine Chunks** zurückgegeben werden (z.B. leere Liste), soll die Funktion **keinen LLM-Aufruf** machen, sondern einen verständlichen Hinweis-String zurückgeben, z.B.:
#    > "Es konnten keine passenden Textstellen gefunden werden."
#
# Implementieren Sie diese Änderungen direkt in der Funktion `answer_query` oben.

# %% [markdown]
# _Hinweis: Sie müssen hier keine neue Zelle schreiben. Passen Sie die bestehende Implementierung von `answer_query` direkt an._

# %% [markdown]
# ### B4. Fragen und Kriterien für eine Evaluation des RAG-Systems (10 Punkte)
#
# Sie haben in diesem Notebook ein RAG-System aufgebaut, das Fragen zum Thema
# **„Jugend, Politik, Umwelt & Partizipation“** beantwortet.
#
# In dieser Aufgabe sollen Sie das LLM nutzen, um:
#
# 1. sinnvolle **Evaluationsfragen** zu generieren, mit denen man das System testen könnte, und
# 2. **Kriterien** vorschlagen zu lassen, auf die man bei der Evaluation achten sollte.
#
# ---
#
# #### B4.1 – Funktion `generate_eval_questions` implementieren
#
# Implementieren Sie eine Funktion, die mit Hilfe des OpenAI-Clients _**10**_ Evaluationsfragen generiert.
#
# **Anforderungen:**
#
# 1. Signatur:
#    ```python
#    def generate_eval_questions(chunks, num_chunks: int = 5) -> str:
#        ...

# %%
# def generate_eval_questions(chunks, num_chunks) -> list:

#     # B4.2 – Kriterien für die Auswertung generieren

#     # TODO (B4.2):
#     # - eigenen Systemprompt definieren (Evaluationsexpert*in) 
#     # - jeden chunk aus dem sample in den prompt injecten
#     # - jede generierte Frage in die Liste einfügen

#     questions = []
#     prompt_eval = (
#         "TODO: Formulieren Sie hier eine Anfrage, in der Sie das Modell bitten, "
#         "Fragen zu genierieren, die zur Evaluation eines "
#         "RAG-Systems (Jugend, Politik, Umwelt & Partizipation) achten sollte. " 
#         "Es soll genau eine Frage, und nur die Frage ausgegeben werden"
#     )

# %%
# def generate_eval_questions(chunks, num_chunks) -> list:
#     questions = []
    
#     prompt_eval = (
#         "Ich habe ein RAG-Modell erstellt, welche sich auf die Themen Umweltschutz, Politik und Jugend fokussiert. Bitte generiere mit hierzu 10 Fragen, sodass ich das Modell überprüfen kann."
#     )
#     question = None
#     for attempt in range(5):
#         try:
#             completion = openai_client.chat.completions.create(
#                 model="gpt-3.5-turbo",
#                 messages=[{"role": "user", "content": prompt_eval}]
#     )
# question = completion.choices[0].message.content.strip()
# if question:
#     break
# except Exception is None:
# question = "Error: could not generate question."
# qa_pairs.append((chunk, question))
# return qa_pairs
# questions = generate_questions_for_random_chunks(chunks_a, num_chunks=5, max_retries
# for i, (chunk, q) in enumerate(questions, 1):
# print(f"Q{i}: {q}\n From chunk preview: {chunk[:120]}...\n")

# %%
# def generate_eval_questions(chunks, num_chunks: int = 5, max_retries: int = 2):
#     selected_chunks = random.sample(chunks, num_chunks)
#     qa_pairs = []

#     for chunk in selected_chunks:
#         prompt = prompt = (
#             "Ich habe ein RAG-Modell erstellt, welche sich auf die Themen Umweltschutz, Politik und Jugend fokussiert. Bitte generiere mit hierzu 10 Fragen, sodass ich das Modell überprüfen kann. Hier der Chunk" + chunk + ""
#         )

#         question = None
#         for attempt in range(max_retries):
#             try:
#                 completion = openai_client.chat.completions.create(
#                     model="gpt-4o-mini",
#                     messages=[{"role": "user", "content": prompt}]
#                 )
#                 question = completion.choices[0].message.content.strip()
#                 if question:
#                     break
#             except Exception as e:
#                 print("Error while generating question, retrying...", e)

#         if question is None:
#             question = "Error: could not generate question."

#         qa_pairs.append((chunk, question))

#     return qa_pairs

# %%
# def generate_eval_questions(chunks, num_chunks: int = 5, max_retries: int = 2) -> list:
#     selected_chunks = random.sample(chunks, num_chunks)
#     questions = []

#     for chunk in selected_chunks:
#         prompt = prompt = (
#             "Ich habe ein RAG-Modell erstellt, welche sich auf die Themen Umweltschutz, Politik und Jugend fokussiert. Bitte generiere mit hierzu 10 Fragen, sodass ich das Modell überprüfen kann. Hier der Chunk" + chunk + ""
#         )

#         question = None
#         for attempt in range(max_retries):
#             try:
#                 completion = openai_client.chat.completions.create(
#                     model="gpt-4o-mini",
#                     messages=[{"role": "user", "content": prompt}]
#                 )
#                 question = completion.choices[0].message.content.strip()
#                 if question:
#                     break
#             except Exception as e:
#                 print("Error while generating question, retrying...", e)

#         if question is None:
#             question = "Error: could not generate question."

#         questions.append((chunk, question))

#     return questions

# %%
def generate_eval_questions(chunks, num_chunks: int = 5, max_retries: int = 2) -> list:
    selected_chunks = random.sample(chunks, num_chunks)
    questions = []

    for chunk in selected_chunks:
        prompt = prompt = (
            "Ich habe ein RAG-Modell erstellt, welche sich auf die Themen Umweltschutz, Politik und Jugend fokussiert. Bitte generiere mit hierzu 10 Fragen, sodass ich das Modell überprüfen kann. Hier der Chunk" + chunk + ""
        )

        question = None
        for attempt in range(max_retries):
            try:
                completion = openai_client.chat.completions.create(
                    model="gpt-4o-mini",
                    messages=[{"role": "user", "content": prompt}]
                )
                question = completion.choices[0].message.content.strip()
                if question:
                    break
            except Exception as e:
                print("Error while generating question, retrying...", e)

        if question is None:
            question = "Error: could not generate question."

        questions.append((chunk, question))

    return questions

# %%
# questions = generate_eval_questions()
# print(questions)

# %%
questions = generate_eval_questions(chunks, num_chunks=5, max_retries=2)
for i, (chunk, q) in enumerate(questions, 1):
    print(f"Q{i}: {q}\n  From chunk preview: {chunk[:120]}...\n")
# Out:
# Q1: Hier sind 10 Fragen, die du verwenden kannst, um dein RAG-Modell zu überprüfen, basierend auf den Themen Umweltschutz, Politik und Jugend:
#
# 1. **Umweltschutz**: Welche Rolle spielt die Jugend im Kampf gegen den Klimawandel, und welche Aktionen haben sie in den letzten Jahren unternommen, um auf Umweltanliegen aufmerksam zu machen?
#
# 2. **Politik**: Inwiefern beeinflusst die politische Bildung der Jugend ihre Beteiligung an sozialen Bewegungen, insbesondere in Bezug auf Umwelt- und Gleichstellungsfragen?
#
# 3. **Umweltschutz**: Welche spezifischen Projekte oder Förderprogramme, wie die der bpb oder des Bundesministeriums des Inneren, sind besonders darauf ausgerichtet, junge Menschen im Bereich Umweltschutz zu unterstützen?
#
# 4. **Politik**: Wie wird im politischen Diskurs der Zusammenhang zwischen Umweltschutz und sozialen Gerechtigkeitsthemen, wie Diskriminierung und Identität, thematisiert?
#
# 5. **Jugendliche Initiativen**: Kannst du Beispiele für erfolgreiche Jugendinitiativen nennen, die sich für die Rechte von marginalisierten Gruppen einsetzen oder auf Umweltprobleme aufmerksam machen?
#
# 6. **Intersektionalität**: Was bedeutet intersektionale politische Bildungsarbeit, und wie kann sie dazu beitragen, das Bewusstsein für Umweltschutz innerhalb der Jugend zu schärfen?
#
# 7. **Förderung von Bildungsprojekten**: Wie können Initiativen, die sich mit machtsensibler und diversitätsorientierter Bildungsarbeit beschäftigen, die politische Mitbestimmung von Jugendlichen fördern?
#
# 8. **Frankfurter Schule**: Inwiefern sind die Ansätze der Frankfurter Schule für die moderne politische Bildung und das Verständnis von Umweltschutz relevant?
#
# 9. **Digitaler Aktivismus**: Welche Rolle spielt digitaler Aktivismus in der Unterstützung von Umweltschützer*innen und politischen Bewegungen unter Jugendlichen?
#
# 10. **Zukunftsperspektiven**: Was sind die größten Herausforderungen und Chancen, die sich für die Jugend im Bereich Umwelt- und Sozialpolitik im Kontext der aktuellen globalen Veränderungen ergeben?
#
# Diese Fragen decken eine Vielzahl von Aspekten ab, die alle Themengebiete deines RAG-Modells betreffen und helfen dir somit, die Relevanz und Präzision deines Modells zu überprüfen.
#   From chunk preview: Klingt nice, oder? Möglich geworden ist dies unter anderem, weil der Fachbereich
# „Politische Bildung und plurale Demokr...
#
# Q2: Hier sind 10 Fragen, die du verwenden kannst, um dein RAG-Modell zu überprüfen. Die Fragen beziehen sich auf die Themen Umweltschutz, Politik und Jugend, wie sie in deinem bereitgestellten Chunk angesprochen werden:
#
# 1. **Wer sind deiner Meinung nach die wichtigsten Akteure im Umwelt- und Klimaschutz in Deutschland?** (Bitte wähle drei aus der Liste aus.)
#
# 2. **Wie bewertest du die Maßnahmen der Bundesregierung zum Klima- und Umweltschutz?** (Genug, eher genug, eher nicht genug, nicht genug.)
#
# 3. **Halten junge Menschen ihre eigene Verantwortung für den Umweltschutz für wichtig?** (Ja, nein, vielleicht.)
#
# 4. **Was sollten Städte und Gemeinden deiner Meinung nach tun, um den Umweltschutz zu verbessern?** (Offene Antwort)
#
# 5. **Wie beurteilst du die Rolle der Industrie im Hinblick auf den Klimaschutz?** (Genug, eher genug, eher nicht genug, nicht genug.)
#
# 6. **Welchen Einfluss haben Bildungseinrichtungen auf das Bewusstsein für Umweltschutz unter Jugendlichen?** (Großen Einfluss, mittleren Einfluss, geringen Einfluss, keinen Einfluss.)
#
# 7. **Welche konkreten Maßnahmen zum Umweltschutz wünscht du dir von der Bundesregierung?** (Offene Antwort)
#
# 8. **Meinst du, dass Medien ausreichend über Umwelt- und Klimafragen berichten?** (Ja, nein, teilweise.)
#
# 9. **Wie wichtig ist dir das Thema Umweltschutz im Vergleich zu anderen politischen Themen?** (Sehr wichtig, wichtig, weniger wichtig, unimportant.)
#
# 10. **Wie schätzt du die zukünftigen Möglichkeiten der Jugend ein, Einfluss auf Umwelt- und Klimapolitik zu nehmen?** (Hoch, mittel, gering, keine Möglichkeit.)
#
# Diese Fragen sind darauf ausgelegt, unterschiedliche Perspektiven und Meinungen zur Rolle von Jugendlichen, Politik und Industrie im Kontext des Umweltschutzes zu erfassen.
#   From chunk preview: Ihrer Ansicht nach machen vor allem jede und jeder Einzelne (88 Prozent),
# die Industrie (88 Prozent) sowie die Bundesr...
#
# Q3: Hier sind 10 Fragen, die du verwenden kannst, um dein RAG-Modell auf die Themen Umweltschutz, Politik und Jugend zu überprüfen:
#
# 1. **Welche langfristigen Auswirkungen siehst du in Bezug auf die Umwelt durch den Anstieg des Online-Shoppings?**
#
# 2. **Inwiefern könnte die Digitalisierung die Beziehung der Jugendlichen zur Natur verändern?**
#
# 3. **Wie wichtig erachtest du den Einsatz digitaler Plattformen zur Aufklärung über Umwelt- und Klimaschutz?**
#
# 4. **Glaubst du, dass die Herstellung von digitalen Geräten wie Smartphones mehr Umweltschäden verursacht als die Produkte, die sie ersetzen? Warum oder warum nicht?**
#
# 5. **Auf welche Weise kann Künstliche Intelligenz (KI) dazu beitragen, Umweltprobleme zu erkennen und Lösungen zu entwickeln?**
#
# 6. **Siehst du positive Aspekte der Digitalisierung hinsichtlich der Zugänglichkeit umweltfreundlicher Produkte und Dienstleistungen?**
#
# 7. **Inwiefern könnte der hohe Stromverbrauch von Rechenzentren einen signifikanten Einfluss auf das Klima haben, und was sollte dagegen unternommen werden?**
#
# 8. **Welche Rolle spielen intelligente, selbstfahrende Autos in der Reduzierung des Verkehrsaufkommens und dadurch der Umweltbelastungen?**
#
# 9. **Findest du, dass das Bewusstsein für die Umweltfolgen der Digitalisierung unter Jugendlichen ausreichend ausgeprägt ist?**
#
# 10. **Wie sollten Regierungen und Entscheidungsträger die Risiken und Chancen der Digitalisierung im Hinblick auf Umwelt und Klima angehen?**
#
# Diese Fragen decken verschiedene Aspekte des Themas ab und helfen dir, das Verständnis und die Meinungen der Befragten zu erfassen.
#   From chunk preview: Es zeigt sich: Bei der Digitalisierung werden sowohl Chancen als auch Risiken für Umwelt und Klima
# erwartet. Eine einde...
#
# Q4: Hier sind 10 Fragen, die sich auf die Themen Umweltschutz, Politik und Jugend beziehen und zur Überprüfung Ihres RAG-Modells genutzt werden können:
#
# 1. Wie bewerten junge Menschen im Alter von 14 bis 22 Jahren die Wichtigkeit des Themas Umwelt- und Klimaschutz im Vergleich zu sozialen Themen wie sozialer Gerechtigkeit und Bildung?
#
# 2. Welche prozentuale Anzahl der befragten jungen Menschen hält Umwelt- und Klimaschutz für sehr wichtig oder eher wichtig?
#
# 3. In welcher Altersgruppe wurde die repräsentative Befragung durchgeführt, und wie viele Teilnehmer waren insgesamt befragt?
#
# 4. Welche Gruppen von jungen Menschen wurden in der Umfrage identifiziert (z. B. Idealisten, Pragmatische, Distanzierten) und wie schätzen sie die Wichtigkeit des Umwelt- und Klimaschutzes ein?
#
# 5. Welche anderen gesellschaftlichen Probleme wurden in der Umfrage genannt, und wie wurden diese im Vergleich zum Umwelt- und Klimaschutz bewertet?
#
# 6. Wie wichtig ist den Befragten die politische Teilhabe, besonders das Wählen gehen, und welche Einstellungen zeigen sie dazu?
#
# 7. Was sind die drei wichtigsten gesellschaftlichen Probleme, die die befragten jungen Menschen laut der Statistik als relevant erachten?
#
# 8. Wie hoch ist der Anteil der „Idealistischen“ Gruppe, der den Umwelt- und Klimaschutz als wichtig ansieht?
#
# 9. Welche Themen wurden als weniger wichtig von den jungen Befragten eingeschätzt, und was könnte dies über ihre Prioritäten aussagen?
#
# 10. Inwiefern wird die Meinung der jungen Menschen über Klimaschutz und Demokratie in der gesellschaftlichen Diskussion berücksichtigt und in politischen Entscheidungen reflektiert?
#
# Diese Fragen können helfen, die Leistungsfähigkeit des RAG-Modells im Hinblick auf das Verständnis und die Ableitung von Informationen aus den gegebenen Texten zu testen.
#   From chunk preview: deutlich über dem Durchschnitt   deutlich unter dem Durchschnitt   etwa im Durchschnitt
# * Die Angaben sind signifikant i...
#
# Q5: Hier sind 10 Fragen, die dazu dienen können, dein RAG-Modell zu überprüfen und die Themen Umweltschutz, Politik und Jugend zu reflektieren:
#
# 1. **Was sind die wesentlichen Merkmale der Intersektionalität in Bezug auf soziale Ungleichheiten in der politischen Bildung?**
#
# 2. **Wie können Machtverhältnisse wie Rassismus und Sexismus individuelle Teilhabemöglichkeiten in der Gesellschaft beeinflussen? Nennen Sie Beispiele.**
#
# 3. **Inwiefern spielt Empowerment eine Rolle in der politischen Bildung für benachteiligte Gruppen?**
#
# 4. **Welchen Einfluss haben bildungspolitische Organisationen auf die Reproduktion sozialer Ungleichheiten in der Gesellschaft?**
#
# 5. **Wie kann ein intersektionaler Ansatz dazu beitragen, die Stimmen und Bedürfnisse marginalisierter Gruppen zu stärken?**
#
# 6. **Was wird unter dem Begriff „Beutelsbacher Konsens“ verstanden, und welche Herausforderungen ergeben sich daraus für die politische Bildung?**
#
# 7. **Wie kann der Ansatz der politischen Bildung die Verantwortung für gesellschaftliche Privilegien adressieren und einen solidarischen Umgang fördern?**
#
# 8. **Welche Handlungsmöglichkeiten ergeben sich aus der Analyse der Verwobenheiten von verschiedenen Diskriminierungslinien für soziale Veränderung?**
#
# 9. **Wie kannst du, als Jugendlicher oder in einem Jugendprojekt, aktiv zur politischen Bildung und zum Umweltschutz beitragen?**
#
# 10. **Welche Rolle spielen historische Zusammenhänge in der politischen Bildung, insbesondere in Bezug auf marginalisierte Gruppen?**
#
# Diese Fragen können dir helfen, die Ansätze und Inhalte deines RAG-Modells zu testen und zu vertiefen sowie die Breite und Tiefe der behandelten Themen zu reflektieren.
#   From chunk preview: The Public Nature of Private Violence. (New York: Routledge, 1994), S. 93 –118, S. 97 185. Intersektionale politische
# ...

# %% [markdown]
# ---
# ## Ende der Prüfung
#
# Überprüfen Sie, ob alle Code-Zellen ausgeführt wurden und alle Antworten (auch die theoretischen Fragen) eingetragen sind.
#
# Viel Erfolg!

# %% [markdown]
# ### Jupyter notebook --footer info-- (please always provide this at the end of each notebook)

# %%
import os
import platform
import socket
from platform import python_version
from datetime import datetime

print('-----------------------------------')
print(os.name.upper())
print(platform.system(), '|', platform.release())
print('Datetime:', datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
print('Python Version:', python_version())
print('IP Address:', socket.gethostbyname(socket.gethostname()))
print('-----------------------------------')
# Out:
# -----------------------------------
# NT
# Windows | 11
# Datetime: 2025-12-15 11:30:48
# Python Version: 3.13.9
# IP Address: 160.85.146.34
# -----------------------------------
